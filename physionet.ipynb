# %% [markdown]
# Load data

# %%
from physionet_data_loader import PhysionetDataLoader
import mne

mne.set_log_level('WARNING')
subject_id = 'S003'
data_dir = r"D:\STUDIA\ZPB\eeg-motor-movementimagery-dataset-1.0.0\files"

data_loader = PhysionetDataLoader(data_dir)
raw = data_loader.load_subject_data(subject_id)

events, event_id = mne.events_from_annotations(raw)
print(f"Events: {events}")
print(f"Event IDs: {event_id}")

labels_to_consider = ['ILH', 'IRH', 'IBH', 'IBF']
events_to_consider = [event_id[label] for label in labels_to_consider]
epochs = mne.Epochs(
    raw, events, event_id=events_to_consider,
    tmin=0.0, tmax=4.0,
    preload=True,
    baseline=None,
    reject_by_annotation=True
)


epochs_data = epochs.get_data()
print(f"Original epochs shape: {epochs_data.shape}")

# Trim the last sample to change shape from (4, 64, 641) to (4, 64, 640)
epochs_data = epochs_data[:, :, :-1]
print(f"Trimmed epochs shape: {epochs_data.shape}")

epochs = mne.EpochsArray(epochs_data, epochs.info, 
                        events=epochs.events, 
                        tmin=epochs.tmin,
                        event_id=epochs.event_id)

print(f"Epochs shape: {epochs.get_data().shape}")
for label in labels_to_consider:
    print(f"Number of epochs for {label}: {len(epochs[event_id[label]])}")
    print(f"Epochs shape for {label}: {epochs[event_id[label]].get_data().shape}")
# Out:
# Successfully applied 10-05 montage to 64 channels out of 64
# Successfully applied 10-05 montage to 64 channels out of 64
# Successfully applied 10-05 montage to 64 channels out of 64
# Successfully applied 10-05 montage to 64 channels out of 64
# Successfully applied 10-05 montage to 64 channels out of 64
# Successfully applied 10-05 montage to 64 channels out of 64
# Successfully applied 10-05 montage to 64 channels out of 64
# Successfully applied 10-05 montage to 64 channels out of 64
# Successfully applied 10-05 montage to 64 channels out of 64
# Successfully applied 10-05 montage to 64 channels out of 64
# Successfully applied 10-05 montage to 64 channels out of 64
# Successfully applied 10-05 montage to 64 channels out of 64
# Successfully applied 10-05 montage to 64 channels out of 64
# Successfully applied 10-05 montage to 64 channels out of 64
# Events: [[     0      0      8]
#  [  9760      0      8]
#  [ 19520      0      8]
#  ...
#  [257456      0      4]
#  [258112      0      8]
#  [258784      0      3]]
# Event IDs: {'BF': 1, 'BH': 2, 'IBF': 3, 'IBH': 4, 'ILH': 5, 'IRH': 6, 'LH': 7, 'R': 8, 'RH': 9}
# Original epochs shape: (120, 64, 641)
# Trimmed epochs shape: (120, 64, 640)
# Number of epochs: 120
# Epochs shape: (120, 64, 640)
# Number of epochs for ILH: 1
# Epochs shape for ILH: (1, 64, 640)
# Number of epochs for IRH: 1
# Epochs shape for IRH: (1, 64, 640)
# Number of epochs for IBH: 1
# Epochs shape for IBH: (1, 64, 640)
# Number of epochs for IBF: 1
# Epochs shape for IBF: (1, 64, 640)
# C:\Users\Mateuusz\AppData\Local\Temp\ipykernel_20668\2496579408.py:27: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   epochs_data = epochs.get_data()
# C:\Users\Mateuusz\AppData\Local\Temp\ipykernel_20668\2496579408.py:43: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   print(f"Epochs shape: {epochs.get_data().shape}")
# C:\Users\Mateuusz\AppData\Local\Temp\ipykernel_20668\2496579408.py:48: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   print(f"Epochs shape for {label}: {epochs[event_id[label]].get_data().shape}")
# C:\Users\Mateuusz\AppData\Local\Temp\ipykernel_20668\2496579408.py:48: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   print(f"Epochs shape for {label}: {epochs[event_id[label]].get_data().shape}")
# C:\Users\Mateuusz\AppData\Local\Temp\ipykernel_20668\2496579408.py:48: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   print(f"Epochs shape for {label}: {epochs[event_id[label]].get_data().shape}")
# C:\Users\Mateuusz\AppData\Local\Temp\ipykernel_20668\2496579408.py:48: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   print(f"Epochs shape for {label}: {epochs[event_id[label]].get_data().shape}")

# %% [markdown]
# Inspect data

# %%
# Inspect data
raw.plot(n_channels=10, duration=5, start=0, show=True)

# Plot topomaps of each class
for label in labels_to_consider:
    mi = event_id[label]
    print(f"Plotting topomap for {label} (event ID: {mi})")
    epochs[mi].compute_psd().plot_topomap()

# %% [markdown]
# Test data scaling (experiment)

# %%
# # Standardize channel data
# scaler = mne.decoding.Scaler(epochs.info, scalings='median')
# X_scaled = scaler.fit_transform(epochs.get_data())  # Returns X array with shape (n_epochs, n_channels, n_times)

# # Plot topomaps of each class
# for label in labels_to_consider:
#     mi = event_id[label]
#     print(f"Plotting topomap for {label} (event ID: {mi})")
    
#     # Extract data for the specific class
#     class_data = X_scaled[epochs.events[:, 2] == mi]
    
#     import matplotlib.pyplot as plt

#     # Initialize a figure for the combined plot
#     fig, axes = plt.subplots(1, len([(0, 4), (4, 8), (8, 12), (12, 30), (30, 45)]), figsize=(20, 5))
#     fig.suptitle(f"Topomaps for {label}")

#     for ax, (fmin, fmax) in zip(axes, [(0, 4), (4, 8), (8, 12), (12, 30), (30, 45)]):
#         # Filter the data
#         filtered_data = mne.filter.filter_data(class_data, sfreq=epochs.info['sfreq'], l_freq=fmin, h_freq=fmax)
        
#         # Compute PSD and plot topomap
#         psd, freqs = mne.time_frequency.psd_array_multitaper(filtered_data, sfreq=epochs.info['sfreq'], fmin=fmin, fmax=fmax)
#         avg_psd = psd.mean(axis=0)
#         im, _ = mne.viz.plot_topomap(avg_psd.mean(axis=1), epochs.info, axes=ax, show=False)
#         ax.set_title(f"{fmin}-{fmax} Hz")

#     # Add a colorbar to the figure
#     cbar = fig.colorbar(im, ax=axes, orientation='vertical')
#     cbar.set_label('Power (dB)')

#     plt.tight_layout()
#     plt.show()

# %% [markdown]
# BF looks like contaminated by some artifact (electrode loosening?)

# %% [markdown]
# Preprocess data

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, SpatialDropout2D,
    BatchNormalization, Flatten, Dense, LeakyReLU
)
from tensorflow.keras.optimizers import Adam

electrode_pairs = [
    ('FC5', 'FC6'), ('FC3', 'FC4'), ('FC1', 'FC2'),
    ('C5', 'C6'), ('C3', 'C4'), ('C1', 'C2'),
    ('CP5', 'CP6'), ('CP3', 'CP4'), ('CP1', 'CP2')
]

def preprocess_data(epochs):
    """Convert MNE epochs to CNN-ready format with electrode pairs."""
    data = epochs.get_data()  # (n_epochs, n_channels, n_times)
    labels = epochs.events[:, -1]
    
    X, y = [], []
    for epoch_idx in range(data.shape[0]):
        epoch_data = data[epoch_idx]  # (n_channels, 640)
        for ch1, ch2 in electrode_pairs:
            # Get channel indices
            idx1 = epochs.ch_names.index(ch1)
            idx2 = epochs.ch_names.index(ch2)
            
            # Concatenate and reshape to (640, 2)
            pair_data = np.hstack([epoch_data[idx1], epoch_data[idx2]]).reshape(640, 2)
            X.append(pair_data)
        y.extend([labels[epoch_idx]] * len(electrode_pairs))  # Same label for all pairs
    
    X = np.array(X)[..., np.newaxis]  # Add channel dimension (n_samples, 640, 2, 1)
    y = np.array(y)
    return X, y

X, y = preprocess_data(epochs)
print(f"Preprocessed data shape: {X.shape}")
# Out:
# C:\Users\Mateuusz\AppData\Local\Temp\ipykernel_20668\1617446336.py:19: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = epochs.get_data()  # (n_epochs, n_channels, n_times)

# %%
# Out:
# Preprocessed data shape: (1080, 640, 2, 1)

# %% [markdown]
# Train

# %%
def build_model(input_shape=(640, 2, 1)):
    model = Sequential([
        # Temporal Convolution
        Conv2D(25, (11, 1), padding='valid', input_shape=input_shape),
        LeakyReLU(alpha=0.01),
        SpatialDropout2D(0.5),
        
        # Spatial Convolution
        Conv2D(25, (1, 2), padding='valid'),
        BatchNormalization(),
        LeakyReLU(alpha=0.01),
        MaxPooling2D((3, 1), strides=(3, 1)),
        
        # Temporal Convolution
        Conv2D(50, (11, 1), padding='valid'),
        LeakyReLU(alpha=0.01),
        SpatialDropout2D(0.5),
        MaxPooling2D((3, 1), strides=(3, 1)),
        
        # Temporal Convolution
        Conv2D(100, (11, 1), padding='valid'),
        BatchNormalization(),
        LeakyReLU(alpha=0.01),
        SpatialDropout2D(0.5),
        MaxPooling2D((3, 1), strides=(3, 1)),
        
        # Temporal Convolution
        Conv2D(200, (11, 1), padding='valid'),
        BatchNormalization(),
        LeakyReLU(alpha=0.01),
        MaxPooling2D((2, 1), strides=(2, 1)),
        
        Flatten(),
        Dense(4, activation='softmax')
    ])
    
    model.compile(
        optimizer=Adam(learning_rate=1e-5),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# ===== Training =====
def train_model(X_train, y_train, X_val, y_val, epochs=2000, batch_size=32):
    model = build_model()
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        verbose=1
    )
    return model, history

# encode the labels
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.1, stratify=y_encoded, random_state=11
)

# there is no window offseting, so we can shuffle data normally
# however, i think this needs to be verified as the data can drift
# split_point = int(0.9 * len(X))
# X_train, X_test = X[:split_point], X[split_point:]
# y_train, y_test = y_encoded[:split_point], y_encoded[split_point:]

print(f"Train data shape: {X_train.shape}, Train labels shape: {y_train.shape}")
print(f"Sample of X_train: {X_train[0]}")
print(f"Sample of y_train: {y_train[0]}")
# Out:
# Train data shape: (972, 640, 2, 1), Train labels shape: (972,)
# Sample of X_train: [[[-6.40e-05]
#   [-6.00e-05]]
#
#  [[-6.90e-05]
#   [-9.10e-05]]
#
#  [[-1.12e-04]
#   [-9.40e-05]]
#
#  ...
#
#  [[ 8.20e-05]
#   [ 1.22e-04]]
#
#  [[ 1.59e-04]
#   [ 1.80e-04]]
#
#  [[ 2.27e-04]
#   [ 2.71e-04]]]
# Sample of y_train: 0

# %%
model, history = train_model(X_train, y_train, X_test, y_test)
# Out:
# c:\Users\Mateuusz\mne-python\1.7.1_0\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Mateuusz\mne-python\1.7.1_0\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.2682 - loss: 1.4280 - val_accuracy: 0.2500 - val_loss: 1.3863
# Epoch 2/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.2385 - loss: 1.3993 - val_accuracy: 0.2500 - val_loss: 1.3863
# Epoch 3/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.2636 - loss: 1.3874 - val_accuracy: 0.2500 - val_loss: 1.3863
# Epoch 4/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.2689 - loss: 1.3881 - val_accuracy: 0.2500 - val_loss: 1.3863
# Epoch 5/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.2566 - loss: 1.3861 - val_accuracy: 0.2500 - val_loss: 1.3863
# Epoch 6/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.2784 - loss: 1.3879 - val_accuracy: 0.2500 - val_loss: 1.3863
# Epoch 7/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.2739 - loss: 1.3857 - val_accuracy: 0.2500 - val_loss: 1.3863
# Epoch 8/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.2519 - loss: 1.3861 - val_accuracy: 0.2500 - val_loss: 1.3863
# Epoch 9/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.2644 - loss: 1.3842 - val_accuracy: 0.2407 - val_loss: 1.3863
# Epoch 10/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3029 - loss: 1.3831 - val_accuracy: 0.2500 - val_loss: 1.3863
# Epoch 11/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.2772 - loss: 1.3859 - val_accuracy: 0.2500 - val_loss: 1.3862
# Epoch 12/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.2562 - loss: 1.3842 - val_accuracy: 0.2500 - val_loss: 1.3863
# Epoch 13/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.2689 - loss: 1.3862 - val_accuracy: 0.2500 - val_loss: 1.3863
# Epoch 14/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.2320 - loss: 1.3887 - val_accuracy: 0.2500 - val_loss: 1.3862
# Epoch 15/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.2722 - loss: 1.3831 - val_accuracy: 0.2500 - val_loss: 1.3863
# Epoch 16/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.2395 - loss: 1.3876 - val_accuracy: 0.2500 - val_loss: 1.3861
# Epoch 17/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.2785 - loss: 1.3782 - val_accuracy: 0.2500 - val_loss: 1.3860
# Epoch 18/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3103 - loss: 1.3678 - val_accuracy: 0.2500 - val_loss: 1.3862
# Epoch 19/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.2418 - loss: 1.3815 - val_accuracy: 0.2593 - val_loss: 1.3852
# Epoch 20/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.2733 - loss: 1.3776 - val_accuracy: 0.2685 - val_loss: 1.3863
# Epoch 21/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.2839 - loss: 1.3822 - val_accuracy: 0.2407 - val_loss: 1.3878
# Epoch 22/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.2798 - loss: 1.3831 - val_accuracy: 0.2407 - val_loss: 1.3882
# Epoch 23/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.2980 - loss: 1.3765 - val_accuracy: 0.2407 - val_loss: 1.3905
# Epoch 24/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.2870 - loss: 1.3763 - val_accuracy: 0.2593 - val_loss: 1.3887
# Epoch 25/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.2864 - loss: 1.3775 - val_accuracy: 0.2407 - val_loss: 1.3908
# Epoch 26/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.2881 - loss: 1.3769 - val_accuracy: 0.2500 - val_loss: 1.4021
# Epoch 27/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3153 - loss: 1.3721 - val_accuracy: 0.2407 - val_loss: 1.4066
# Epoch 28/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.2871 - loss: 1.3734 - val_accuracy: 0.2407 - val_loss: 1.4026
# Epoch 29/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.2921 - loss: 1.3740 - val_accuracy: 0.2407 - val_loss: 1.4902
# Epoch 30/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.2881 - loss: 1.3744 - val_accuracy: 0.2407 - val_loss: 1.4481
# Epoch 31/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.2909 - loss: 1.3757 - val_accuracy: 0.2407 - val_loss: 1.4796
# Epoch 32/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3408 - loss: 1.3606 - val_accuracy: 0.2593 - val_loss: 1.5018
# Epoch 33/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3223 - loss: 1.3597 - val_accuracy: 0.2407 - val_loss: 1.5669
# Epoch 34/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3324 - loss: 1.3655 - val_accuracy: 0.2407 - val_loss: 1.5154
# Epoch 35/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3302 - loss: 1.3612 - val_accuracy: 0.2407 - val_loss: 1.7278
# Epoch 36/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.2860 - loss: 1.3669 - val_accuracy: 0.2407 - val_loss: 1.6173
# Epoch 37/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.2962 - loss: 1.3734 - val_accuracy: 0.2407 - val_loss: 1.6821
# Epoch 38/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3314 - loss: 1.3663 - val_accuracy: 0.2407 - val_loss: 1.5074
# Epoch 39/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.2936 - loss: 1.3740 - val_accuracy: 0.2593 - val_loss: 1.4560
# Epoch 40/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3159 - loss: 1.3627 - val_accuracy: 0.2685 - val_loss: 1.3888
# Epoch 41/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3323 - loss: 1.3564 - val_accuracy: 0.2407 - val_loss: 1.4138
# Epoch 42/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3299 - loss: 1.3627 - val_accuracy: 0.2407 - val_loss: 1.4744
# Epoch 43/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3264 - loss: 1.3473 - val_accuracy: 0.2407 - val_loss: 1.4603
# Epoch 44/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3437 - loss: 1.3396 - val_accuracy: 0.2407 - val_loss: 1.4379
# Epoch 45/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3148 - loss: 1.3495 - val_accuracy: 0.2500 - val_loss: 1.4223
# Epoch 46/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3277 - loss: 1.3509 - val_accuracy: 0.2593 - val_loss: 1.3946
# Epoch 47/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3010 - loss: 1.3570 - val_accuracy: 0.2593 - val_loss: 1.4006
# Epoch 48/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3482 - loss: 1.3402 - val_accuracy: 0.2500 - val_loss: 1.3860
# Epoch 49/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3660 - loss: 1.3511 - val_accuracy: 0.2685 - val_loss: 1.3805
# Epoch 50/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3551 - loss: 1.3429 - val_accuracy: 0.2870 - val_loss: 1.4327
# Epoch 51/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3833 - loss: 1.3335 - val_accuracy: 0.2407 - val_loss: 1.4486
# Epoch 52/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3547 - loss: 1.3343 - val_accuracy: 0.2778 - val_loss: 1.5036
# Epoch 53/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3629 - loss: 1.3302 - val_accuracy: 0.2963 - val_loss: 1.5535
# Epoch 54/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3446 - loss: 1.3342 - val_accuracy: 0.2407 - val_loss: 1.4911
# Epoch 55/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3390 - loss: 1.3430 - val_accuracy: 0.2407 - val_loss: 1.5546
# Epoch 56/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3482 - loss: 1.3426 - val_accuracy: 0.2407 - val_loss: 1.4161
# Epoch 57/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3895 - loss: 1.3247 - val_accuracy: 0.3519 - val_loss: 1.3770
# Epoch 58/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3468 - loss: 1.3269 - val_accuracy: 0.2593 - val_loss: 1.4090
# Epoch 59/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3550 - loss: 1.3251 - val_accuracy: 0.3056 - val_loss: 1.3784
# Epoch 60/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3707 - loss: 1.3333 - val_accuracy: 0.2407 - val_loss: 1.4437
# Epoch 61/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3611 - loss: 1.3335 - val_accuracy: 0.2407 - val_loss: 1.5591
# Epoch 62/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3778 - loss: 1.3244 - val_accuracy: 0.2407 - val_loss: 1.7519
# Epoch 63/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3476 - loss: 1.3403 - val_accuracy: 0.2407 - val_loss: 1.5756
# Epoch 64/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3974 - loss: 1.3160 - val_accuracy: 0.2407 - val_loss: 1.3972
# Epoch 65/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3509 - loss: 1.3236 - val_accuracy: 0.2407 - val_loss: 1.3957
# Epoch 66/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3652 - loss: 1.3054 - val_accuracy: 0.2407 - val_loss: 1.3923
# Epoch 67/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3721 - loss: 1.3114 - val_accuracy: 0.2593 - val_loss: 1.4930
# Epoch 68/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3699 - loss: 1.3148 - val_accuracy: 0.2870 - val_loss: 1.5605
# Epoch 69/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4002 - loss: 1.2971 - val_accuracy: 0.2407 - val_loss: 1.4932
# Epoch 70/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3300 - loss: 1.3241 - val_accuracy: 0.2407 - val_loss: 1.3996
# Epoch 71/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3602 - loss: 1.3011 - val_accuracy: 0.2407 - val_loss: 1.5005
# Epoch 72/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3614 - loss: 1.3331 - val_accuracy: 0.2407 - val_loss: 1.5619
# Epoch 73/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3793 - loss: 1.3062 - val_accuracy: 0.2407 - val_loss: 1.4270
# Epoch 74/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3865 - loss: 1.3020 - val_accuracy: 0.2407 - val_loss: 1.3923
# Epoch 75/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3907 - loss: 1.3158 - val_accuracy: 0.3333 - val_loss: 1.3755
# Epoch 76/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3872 - loss: 1.3023 - val_accuracy: 0.4074 - val_loss: 1.3707
# Epoch 77/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3923 - loss: 1.2912 - val_accuracy: 0.3611 - val_loss: 1.4337
# Epoch 78/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4076 - loss: 1.3097 - val_accuracy: 0.3056 - val_loss: 1.4079
# Epoch 79/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3816 - loss: 1.2846 - val_accuracy: 0.2963 - val_loss: 1.3633
# Epoch 80/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3588 - loss: 1.3170 - val_accuracy: 0.3241 - val_loss: 1.5038
# Epoch 81/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3845 - loss: 1.3090 - val_accuracy: 0.2407 - val_loss: 1.6235
# Epoch 82/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3440 - loss: 1.3301 - val_accuracy: 0.2685 - val_loss: 1.4511
# Epoch 83/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3912 - loss: 1.2980 - val_accuracy: 0.3241 - val_loss: 1.4010
# Epoch 84/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3673 - loss: 1.3043 - val_accuracy: 0.2778 - val_loss: 1.4091
# Epoch 85/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3903 - loss: 1.2965 - val_accuracy: 0.3241 - val_loss: 1.3693
# Epoch 86/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4244 - loss: 1.2868 - val_accuracy: 0.3148 - val_loss: 1.3656
# Epoch 87/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3722 - loss: 1.3015 - val_accuracy: 0.3611 - val_loss: 1.3494
# Epoch 88/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4170 - loss: 1.2823 - val_accuracy: 0.3704 - val_loss: 1.3496
# Epoch 89/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3932 - loss: 1.2896 - val_accuracy: 0.2593 - val_loss: 1.3709
# Epoch 90/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3969 - loss: 1.2761 - val_accuracy: 0.2778 - val_loss: 1.3692
# Epoch 91/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3845 - loss: 1.2862 - val_accuracy: 0.2870 - val_loss: 1.3553
# Epoch 92/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4147 - loss: 1.2715 - val_accuracy: 0.3241 - val_loss: 1.3544
# Epoch 93/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3963 - loss: 1.2861 - val_accuracy: 0.2963 - val_loss: 1.3679
# Epoch 94/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4296 - loss: 1.2782 - val_accuracy: 0.2963 - val_loss: 1.3671
# Epoch 95/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4107 - loss: 1.2787 - val_accuracy: 0.2407 - val_loss: 1.3916
# Epoch 96/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4192 - loss: 1.2698 - val_accuracy: 0.2407 - val_loss: 1.4234
# Epoch 97/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3915 - loss: 1.2723 - val_accuracy: 0.2593 - val_loss: 1.3746
# Epoch 98/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4307 - loss: 1.2521 - val_accuracy: 0.3426 - val_loss: 1.3481
# Epoch 99/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4259 - loss: 1.2638 - val_accuracy: 0.4352 - val_loss: 1.3156
# Epoch 100/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4332 - loss: 1.2700 - val_accuracy: 0.4074 - val_loss: 1.3183
# Epoch 101/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4224 - loss: 1.2751 - val_accuracy: 0.4444 - val_loss: 1.3200
# Epoch 102/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4428 - loss: 1.2366 - val_accuracy: 0.2407 - val_loss: 1.3947
# Epoch 103/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4111 - loss: 1.2570 - val_accuracy: 0.3426 - val_loss: 1.3465
# Epoch 104/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4051 - loss: 1.2835 - val_accuracy: 0.3426 - val_loss: 1.3501
# Epoch 105/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4580 - loss: 1.2566 - val_accuracy: 0.3426 - val_loss: 1.3373
# Epoch 106/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3809 - loss: 1.2866 - val_accuracy: 0.2685 - val_loss: 1.3649
# Epoch 107/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4178 - loss: 1.2531 - val_accuracy: 0.2963 - val_loss: 1.3629
# Epoch 108/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4141 - loss: 1.2535 - val_accuracy: 0.2500 - val_loss: 1.3857
# Epoch 109/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4213 - loss: 1.2825 - val_accuracy: 0.2870 - val_loss: 1.3898
# Epoch 110/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4117 - loss: 1.2403 - val_accuracy: 0.3056 - val_loss: 1.3581
# Epoch 111/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4443 - loss: 1.2643 - val_accuracy: 0.2778 - val_loss: 1.3711
# Epoch 112/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4247 - loss: 1.2336 - val_accuracy: 0.3426 - val_loss: 1.3481
# Epoch 113/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4510 - loss: 1.2341 - val_accuracy: 0.4630 - val_loss: 1.3562
# Epoch 114/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4344 - loss: 1.2444 - val_accuracy: 0.3241 - val_loss: 1.4427
# Epoch 115/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4277 - loss: 1.2140 - val_accuracy: 0.3981 - val_loss: 1.3836
# Epoch 116/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3868 - loss: 1.2819 - val_accuracy: 0.2870 - val_loss: 1.3768
# Epoch 117/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4464 - loss: 1.2236 - val_accuracy: 0.2685 - val_loss: 1.3556
# Epoch 118/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4155 - loss: 1.2671 - val_accuracy: 0.3426 - val_loss: 1.3746
# Epoch 119/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4477 - loss: 1.2235 - val_accuracy: 0.3611 - val_loss: 1.3777
# Epoch 120/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4227 - loss: 1.2510 - val_accuracy: 0.3426 - val_loss: 1.3771
# Epoch 121/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4125 - loss: 1.2495 - val_accuracy: 0.3241 - val_loss: 1.3772
# Epoch 122/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4198 - loss: 1.2510 - val_accuracy: 0.2685 - val_loss: 1.3977
# Epoch 123/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4313 - loss: 1.2385 - val_accuracy: 0.3611 - val_loss: 1.3381
# Epoch 124/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4091 - loss: 1.2632 - val_accuracy: 0.3056 - val_loss: 1.3375
# Epoch 125/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4412 - loss: 1.2323 - val_accuracy: 0.3333 - val_loss: 1.3327
# Epoch 126/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4964 - loss: 1.2094 - val_accuracy: 0.2778 - val_loss: 1.4846
# Epoch 127/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4233 - loss: 1.2231 - val_accuracy: 0.2778 - val_loss: 1.5779
# Epoch 128/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4648 - loss: 1.2327 - val_accuracy: 0.2870 - val_loss: 1.5595
# Epoch 129/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4385 - loss: 1.2072 - val_accuracy: 0.2778 - val_loss: 1.3981
# Epoch 130/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.4498 - loss: 1.2216 - val_accuracy: 0.2685 - val_loss: 1.3483
# Epoch 131/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4261 - loss: 1.2236 - val_accuracy: 0.3519 - val_loss: 1.3372
# Epoch 132/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4470 - loss: 1.2107 - val_accuracy: 0.4722 - val_loss: 1.3053
# Epoch 133/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4277 - loss: 1.2154 - val_accuracy: 0.4352 - val_loss: 1.2963
# Epoch 134/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5098 - loss: 1.1631 - val_accuracy: 0.2593 - val_loss: 1.3404
# Epoch 135/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4398 - loss: 1.1915 - val_accuracy: 0.3333 - val_loss: 1.3203
# Epoch 136/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4550 - loss: 1.2057 - val_accuracy: 0.3333 - val_loss: 1.3480
# Epoch 137/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4658 - loss: 1.1882 - val_accuracy: 0.4352 - val_loss: 1.3379
# Epoch 138/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4796 - loss: 1.2023 - val_accuracy: 0.4815 - val_loss: 1.3415
# Epoch 139/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4476 - loss: 1.1821 - val_accuracy: 0.3981 - val_loss: 1.3648
# Epoch 140/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4634 - loss: 1.2001 - val_accuracy: 0.4074 - val_loss: 1.3306
# Epoch 141/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4672 - loss: 1.1727 - val_accuracy: 0.3241 - val_loss: 1.3629
# Epoch 142/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4875 - loss: 1.1722 - val_accuracy: 0.3333 - val_loss: 1.3785
# Epoch 143/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4827 - loss: 1.1782 - val_accuracy: 0.4352 - val_loss: 1.3435
# Epoch 144/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4577 - loss: 1.1893 - val_accuracy: 0.2685 - val_loss: 1.3608
# Epoch 145/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4549 - loss: 1.1911 - val_accuracy: 0.2870 - val_loss: 1.3669
# Epoch 146/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4864 - loss: 1.1542 - val_accuracy: 0.4167 - val_loss: 1.3546
# Epoch 147/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4726 - loss: 1.1797 - val_accuracy: 0.3148 - val_loss: 1.3537
# Epoch 148/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4769 - loss: 1.1812 - val_accuracy: 0.3056 - val_loss: 1.3738
# Epoch 149/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4809 - loss: 1.1781 - val_accuracy: 0.4259 - val_loss: 1.3273
# Epoch 150/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4747 - loss: 1.1769 - val_accuracy: 0.3981 - val_loss: 1.3503
# Epoch 151/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4574 - loss: 1.1775 - val_accuracy: 0.3796 - val_loss: 1.3362
# Epoch 152/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4834 - loss: 1.1639 - val_accuracy: 0.4722 - val_loss: 1.3126
# Epoch 153/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5091 - loss: 1.1602 - val_accuracy: 0.5185 - val_loss: 1.2936
# Epoch 154/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5032 - loss: 1.1268 - val_accuracy: 0.3241 - val_loss: 1.2892
# Epoch 155/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4644 - loss: 1.1772 - val_accuracy: 0.3981 - val_loss: 1.2919
# Epoch 156/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4946 - loss: 1.1535 - val_accuracy: 0.4167 - val_loss: 1.3032
# Epoch 157/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5013 - loss: 1.1381 - val_accuracy: 0.3056 - val_loss: 1.3257
# Epoch 158/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4778 - loss: 1.1603 - val_accuracy: 0.3148 - val_loss: 1.3272
# Epoch 159/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4822 - loss: 1.1606 - val_accuracy: 0.3889 - val_loss: 1.2415
# Epoch 160/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4759 - loss: 1.1713 - val_accuracy: 0.4352 - val_loss: 1.2773
# Epoch 161/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4599 - loss: 1.1829 - val_accuracy: 0.3796 - val_loss: 1.2859
# Epoch 162/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4717 - loss: 1.1456 - val_accuracy: 0.3148 - val_loss: 1.2839
# Epoch 163/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4813 - loss: 1.1672 - val_accuracy: 0.4259 - val_loss: 1.2630
# Epoch 164/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5032 - loss: 1.1192 - val_accuracy: 0.3611 - val_loss: 1.2601
# Epoch 165/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4988 - loss: 1.1335 - val_accuracy: 0.2963 - val_loss: 1.2884
# Epoch 166/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5009 - loss: 1.1423 - val_accuracy: 0.3148 - val_loss: 1.2811
# Epoch 167/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4771 - loss: 1.1654 - val_accuracy: 0.3241 - val_loss: 1.3045
# Epoch 168/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4836 - loss: 1.1535 - val_accuracy: 0.3241 - val_loss: 1.2650
# Epoch 169/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.4980 - loss: 1.1516 - val_accuracy: 0.4907 - val_loss: 1.2341
# Epoch 170/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4766 - loss: 1.1393 - val_accuracy: 0.3056 - val_loss: 1.2789
# Epoch 171/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5153 - loss: 1.1051 - val_accuracy: 0.2593 - val_loss: 1.3661
# Epoch 172/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5275 - loss: 1.0939 - val_accuracy: 0.2685 - val_loss: 1.4300
# Epoch 173/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4902 - loss: 1.1300 - val_accuracy: 0.3241 - val_loss: 1.3479
# Epoch 174/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4905 - loss: 1.1097 - val_accuracy: 0.2685 - val_loss: 1.4080
# Epoch 175/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5325 - loss: 1.1093 - val_accuracy: 0.2500 - val_loss: 1.4694
# Epoch 176/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5237 - loss: 1.0741 - val_accuracy: 0.2963 - val_loss: 1.4451
# Epoch 177/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5029 - loss: 1.1118 - val_accuracy: 0.2778 - val_loss: 1.3710
# Epoch 178/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5052 - loss: 1.0993 - val_accuracy: 0.4352 - val_loss: 1.2955
# Epoch 179/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5281 - loss: 1.0817 - val_accuracy: 0.4444 - val_loss: 1.2906
# Epoch 180/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4976 - loss: 1.1066 - val_accuracy: 0.3704 - val_loss: 1.2754
# Epoch 181/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4950 - loss: 1.1228 - val_accuracy: 0.3056 - val_loss: 1.3127
# Epoch 182/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5088 - loss: 1.0966 - val_accuracy: 0.3519 - val_loss: 1.3480
# Epoch 183/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5107 - loss: 1.0945 - val_accuracy: 0.3056 - val_loss: 1.3099
# Epoch 184/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5267 - loss: 1.1037 - val_accuracy: 0.3333 - val_loss: 1.2940
# Epoch 185/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5221 - loss: 1.0731 - val_accuracy: 0.2870 - val_loss: 1.3655
# Epoch 186/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5198 - loss: 1.1086 - val_accuracy: 0.2593 - val_loss: 1.3648
# Epoch 187/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4891 - loss: 1.0874 - val_accuracy: 0.5000 - val_loss: 1.3279
# Epoch 188/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4868 - loss: 1.1147 - val_accuracy: 0.3333 - val_loss: 1.2853
# Epoch 189/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5119 - loss: 1.0873 - val_accuracy: 0.3611 - val_loss: 1.2918
# Epoch 190/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5224 - loss: 1.0569 - val_accuracy: 0.2685 - val_loss: 1.3331
# Epoch 191/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5084 - loss: 1.0734 - val_accuracy: 0.3333 - val_loss: 1.3039
# Epoch 192/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5087 - loss: 1.0933 - val_accuracy: 0.3519 - val_loss: 1.2570
# Epoch 193/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4920 - loss: 1.1076 - val_accuracy: 0.3796 - val_loss: 1.2585
# Epoch 194/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5198 - loss: 1.0706 - val_accuracy: 0.3241 - val_loss: 1.2621
# Epoch 195/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4996 - loss: 1.0498 - val_accuracy: 0.3056 - val_loss: 1.2906
# Epoch 196/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5410 - loss: 1.0706 - val_accuracy: 0.3241 - val_loss: 1.2965
# Epoch 197/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5010 - loss: 1.1004 - val_accuracy: 0.2685 - val_loss: 1.3685
# Epoch 198/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5320 - loss: 1.0584 - val_accuracy: 0.2778 - val_loss: 1.3443
# Epoch 199/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5207 - loss: 1.0385 - val_accuracy: 0.3056 - val_loss: 1.2957
# Epoch 200/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5242 - loss: 1.0412 - val_accuracy: 0.2963 - val_loss: 1.3503
# Epoch 201/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5368 - loss: 1.0468 - val_accuracy: 0.3056 - val_loss: 1.2823
# Epoch 202/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5508 - loss: 1.0487 - val_accuracy: 0.3333 - val_loss: 1.2064
# Epoch 203/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5131 - loss: 1.0658 - val_accuracy: 0.3426 - val_loss: 1.2579
# Epoch 204/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5089 - loss: 1.0448 - val_accuracy: 0.2778 - val_loss: 1.3009
# Epoch 205/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5287 - loss: 1.0530 - val_accuracy: 0.3611 - val_loss: 1.2562
# Epoch 206/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5409 - loss: 1.0583 - val_accuracy: 0.4352 - val_loss: 1.2014
# Epoch 207/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5692 - loss: 1.0385 - val_accuracy: 0.3981 - val_loss: 1.2151
# Epoch 208/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5341 - loss: 1.0477 - val_accuracy: 0.3148 - val_loss: 1.2927
# Epoch 209/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5336 - loss: 1.0463 - val_accuracy: 0.3426 - val_loss: 1.2504
# Epoch 210/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5397 - loss: 1.0331 - val_accuracy: 0.3796 - val_loss: 1.2336
# Epoch 211/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5553 - loss: 1.0463 - val_accuracy: 0.3981 - val_loss: 1.2174
# Epoch 212/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5479 - loss: 1.0452 - val_accuracy: 0.3611 - val_loss: 1.2607
# Epoch 213/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5450 - loss: 1.0483 - val_accuracy: 0.3241 - val_loss: 1.3064
# Epoch 214/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5749 - loss: 1.0027 - val_accuracy: 0.2963 - val_loss: 1.3601
# Epoch 215/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5356 - loss: 1.0261 - val_accuracy: 0.3333 - val_loss: 1.3017
# Epoch 216/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5329 - loss: 1.0324 - val_accuracy: 0.4167 - val_loss: 1.2857
# Epoch 217/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5401 - loss: 1.0091 - val_accuracy: 0.3796 - val_loss: 1.3273
# Epoch 218/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5578 - loss: 1.0259 - val_accuracy: 0.3796 - val_loss: 1.2784
# Epoch 219/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5717 - loss: 1.0147 - val_accuracy: 0.4537 - val_loss: 1.1906
# Epoch 220/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5598 - loss: 1.0558 - val_accuracy: 0.4352 - val_loss: 1.1691
# Epoch 221/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5814 - loss: 1.0079 - val_accuracy: 0.3981 - val_loss: 1.2230
# Epoch 222/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5665 - loss: 1.0042 - val_accuracy: 0.4444 - val_loss: 1.1428
# Epoch 223/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5441 - loss: 1.0229 - val_accuracy: 0.4259 - val_loss: 1.1194
# Epoch 224/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5729 - loss: 1.0041 - val_accuracy: 0.3519 - val_loss: 1.2254
# Epoch 225/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5537 - loss: 0.9970 - val_accuracy: 0.3426 - val_loss: 1.2293
# Epoch 226/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5439 - loss: 1.0026 - val_accuracy: 0.2963 - val_loss: 1.3292
# Epoch 227/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5613 - loss: 0.9997 - val_accuracy: 0.2963 - val_loss: 1.3828
# Epoch 228/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5634 - loss: 1.0058 - val_accuracy: 0.3056 - val_loss: 1.3021
# Epoch 229/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5788 - loss: 0.9664 - val_accuracy: 0.3981 - val_loss: 1.2410
# Epoch 230/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6082 - loss: 0.9727 - val_accuracy: 0.4167 - val_loss: 1.3406
# Epoch 231/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5716 - loss: 0.9858 - val_accuracy: 0.3981 - val_loss: 1.3136
# Epoch 232/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5689 - loss: 0.9777 - val_accuracy: 0.3796 - val_loss: 1.2674
# Epoch 233/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5522 - loss: 1.0013 - val_accuracy: 0.4074 - val_loss: 1.2508
# Epoch 234/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5722 - loss: 0.9518 - val_accuracy: 0.2870 - val_loss: 1.3473
# Epoch 235/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5854 - loss: 0.9766 - val_accuracy: 0.2870 - val_loss: 1.3293
# Epoch 236/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.6008 - loss: 0.9575 - val_accuracy: 0.3704 - val_loss: 1.1805
# Epoch 237/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5591 - loss: 1.0085 - val_accuracy: 0.3333 - val_loss: 1.2493
# Epoch 238/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5718 - loss: 0.9781 - val_accuracy: 0.3981 - val_loss: 1.1688
# Epoch 239/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6157 - loss: 0.9311 - val_accuracy: 0.4352 - val_loss: 1.2044
# Epoch 240/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.6014 - loss: 0.9470 - val_accuracy: 0.3611 - val_loss: 1.2348
# Epoch 241/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5522 - loss: 0.9827 - val_accuracy: 0.3704 - val_loss: 1.2526
# Epoch 242/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5973 - loss: 0.9818 - val_accuracy: 0.3519 - val_loss: 1.2644
# Epoch 243/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5997 - loss: 0.9544 - val_accuracy: 0.3426 - val_loss: 1.2664
# Epoch 244/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6222 - loss: 0.9447 - val_accuracy: 0.4444 - val_loss: 1.2090
# Epoch 245/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5519 - loss: 0.9672 - val_accuracy: 0.3426 - val_loss: 1.3010
# Epoch 246/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.6058 - loss: 0.9186 - val_accuracy: 0.3241 - val_loss: 1.2926
# Epoch 247/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5991 - loss: 0.9511 - val_accuracy: 0.4537 - val_loss: 1.1906
# Epoch 248/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.6054 - loss: 0.9554 - val_accuracy: 0.4352 - val_loss: 1.2116
# Epoch 249/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5791 - loss: 0.9778 - val_accuracy: 0.5556 - val_loss: 1.0749
# Epoch 250/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6423 - loss: 0.8955 - val_accuracy: 0.5278 - val_loss: 1.0870
# Epoch 251/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5368 - loss: 0.9862 - val_accuracy: 0.5463 - val_loss: 1.0524
# Epoch 252/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5712 - loss: 0.9637 - val_accuracy: 0.3889 - val_loss: 1.1899
# Epoch 253/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6122 - loss: 0.8975 - val_accuracy: 0.4167 - val_loss: 1.1757
# Epoch 254/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.6095 - loss: 0.9499 - val_accuracy: 0.3981 - val_loss: 1.1809
# Epoch 255/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5906 - loss: 0.9291 - val_accuracy: 0.3889 - val_loss: 1.2389
# Epoch 256/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.6199 - loss: 0.9180 - val_accuracy: 0.4537 - val_loss: 1.2011
# Epoch 257/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5930 - loss: 0.9197 - val_accuracy: 0.4444 - val_loss: 1.1724
# Epoch 258/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6120 - loss: 0.9280 - val_accuracy: 0.3426 - val_loss: 1.2825
# Epoch 259/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.6220 - loss: 0.9094 - val_accuracy: 0.3056 - val_loss: 1.3131
# Epoch 260/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5926 - loss: 0.9249 - val_accuracy: 0.3241 - val_loss: 1.2744
# Epoch 261/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6094 - loss: 0.8825 - val_accuracy: 0.4815 - val_loss: 1.1723
# Epoch 262/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5990 - loss: 0.9323 - val_accuracy: 0.5648 - val_loss: 1.0047
# Epoch 263/2000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9996 - loss: 0.0135 - val_accuracy: 1.0000 - val_loss: 0.0336
# Epoch 1291/2000
# 20/31 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0161
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model, history = train_model(X_train, y_train, X_test, y_test)
#
# Cell In[4], line 47, in train_model(X_train, y_train, X_val, y_val, epochs, batch_size)
#      45 def train_model(X_train, y_train, X_val, y_val, epochs=2000, batch_size=32):
#      46     model = build_model()
# ---> 47     history = model.fit(
#      48         X_train, y_train,
#      49         validation_data=(X_val, y_val),
#      50         epochs=epochs,
#      51         batch_size=batch_size,
#      52         verbose=1
#      53     )
#      54     return model, history
#
# File c:\Users\Mateuusz\mne-python\1.7.1_0\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Mateuusz\mne-python\1.7.1_0\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     callbacks.on_train_batch_end(step, logs)
#     322     if self.stop_training:
#
# File c:\Users\Mateuusz\mne-python\1.7.1_0\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Mateuusz\mne-python\1.7.1_0\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Mateuusz\mne-python\1.7.1_0\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\Mateuusz\mne-python\1.7.1_0\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\Mateuusz\mne-python\1.7.1_0\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Mateuusz\mne-python\1.7.1_0\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\Mateuusz\mne-python\1.7.1_0\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\Mateuusz\mne-python\1.7.1_0\Lib\site-packages\tensorflow\python\eager\context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File c:\Users\Mateuusz\mne-python\1.7.1_0\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# Evaluate

# %%
def evaluate_model(model, X_test, y_test):
    # Calculate accuracy
    y_pred = model.predict(X_test).argmax(axis=1)
    accuracy = accuracy_score(y_test, y_pred)
    
    # Calculate AUC
    y_probs = model.predict(X_test)
    auc = roc_auc_score(y_test, y_probs, multi_class='ovr')
    
    # Classification report
    report = classification_report(y_test, y_pred, target_names=['T1', 'T2', 'T3', 'T4'])
    
    return {
        'accuracy': accuracy,
        'auc': auc,
        'report': report
    }

results = evaluate_model(model, X_test, y_test)
print(f"Test Accuracy: {results['accuracy']:.2%}")
print(f"Test AUC: {results['auc']:.3f}")
print("\nClassification Report:\n", results['report'])
